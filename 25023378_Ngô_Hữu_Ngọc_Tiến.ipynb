# %%
a = int(input())
b = int(input())

a = a ^ b
b = a ^ b
a = a ^ b

print(f"a mới: {a}; b: {b}")
# Out:
# 5
# 7
# a mới: 7; b: 5

# %%
a = int(input())
if (a & (a-1)==0):
  print(f"{a} là lũy thừa của 2")
else:
  print(f"{a} ko phải là lũy thừa của 2")
# Out:
# 4
# 4 là lũy thừa của 2

# %%
m = float(input())
n = float(input())
print (m//n)
# Out:
# 5.5
# 4
# 1.0

# %%
import math
m = int(input())
n = int(input())
result = math.ceil(m / n)
print(result)
# Out:
# 5
# 4
# 2

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# 5
# Odd

# %%
a= int(input())
b = int(input())
if (a and b <= 0):
 print ("yes")
else:
 print ("no")
# Out:
# -2
# -3
# yes

# %%
a = input()
b = input()
if len(a) > len(b):
 print ("True")
else:
  print ("False")
# Out:
# 2,4,5
# 4,5,6
# False

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and a + c > b and b + c > a:
    print("yes")
else:
    print("no")
# Out:
# 4
# 5
# 6
# yes

# %%
nums = [int(input()) for _ in range(4)]
print(f"Số lớn nhất là : {max(nums)}")
# Out:
# 4
# 5
# 6
# 7
# Số lớn nhất là : 7

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# 5
# 5
# 5
# Tam giác đều

# %%
year = int(input())
if ( year % 4 == 0 and year % 100 !=0 ) or ( year % 400 ==0 ):
 print ("yes")
else:
  print ("no")
# Out:
# 400
# yes

# %%
a = float(input())
b = float (input())
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    x = -b / a
    print(f"{x:.2f}")
# Out:
# 4
# 5
# -1.25

# %%
a = float(input("Điểm trung bình của học sinh là: "))
if a >= 8.0:
 print ("Giỏi")
elif a >= 6.5:
 print ("Khá")
elif a >= 5.0:
 print ("Trung Bình")
else:
  print ("Yếu")
# Out:
# Điểm trung bình của học sinh là: 7.5
# Khá

# %%
import math

s = input().strip()
x = float(s)
lamtronlen = math.ceil(x)
lamtronxuong = math.floor(x)
gannhat = math.floor(x + 0.5)
print(lamtronlen, lamtronxuong, gannhat)
# Out:
# 5.5
# 6 5 6

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a == 0:
    print("No")
else:
    if b % a != 0:
        print("No")
    else:
        k = b // a
        if b * k == c and c * k == d:
            print("Yes")
        else:
            print("No")
# Out:
# 2
# 4
# 8
# 16
# Yes
